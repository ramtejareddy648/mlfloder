# %%
### we are handleing with missing values

import seaborn as sns

df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.isnull()  ###it show if any value is null as true
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df.isnull().sum()  ### here we which column has null values total sum
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.shape ### 891 rows and 15 columns
# Out:
# (891, 15)

# %%
### if we delete null values
df.dropna().shape #### after delete null values we have only 182 rows and 15 columns
# Out:
# (182, 15)

# %%
df.shape
# Out:
# (891, 15)

# %%
## here we deleting null values along columns

df.dropna(axis=1,inplace=True) ### after completeing excution here we loss 4 columns

# %%
df.shape
# Out:
# (891, 11)

# %%
df.isnull().sum()  ### here we dont have any null values
# Out:
# survived      0
# pclass        0
# sex           0
# sibsp         0
# parch         0
# fare          0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %% [markdown]
# ##### this not god method deleting null values because we loss more data
#
# ### so we mean median

# %%
sns.histplot(df["age"],kde=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dell\Documents\code\myenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.histplot(df["age"],kde=True)
#
# ...

# %%
df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(df['age']) ### here we got histplot graph if we kde=true we get smooth
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['age'],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df["mean_age"]=df["age"].fillna(df['age']).mean()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone   mean_age
# 0    man        True  NaN  Southampton    no  False  29.699118
# 1  woman       False    C    Cherbourg   yes  False  29.699118
# 2  woman       False  NaN  Southampton   yes   True  29.699118
# 3  woman       False    C  Southampton   yes  False  29.699118
# 4    man        True  NaN  Southampton    no   True  29.699118

# %%
df.isnull().sum()  ###here we didnot have mean_age value null
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# mean_age         0
# dtype: int64

# %%
df["mean_age"]
# Out:
# 0      29.699118
# 1      29.699118
# 2      29.699118
# 3      29.699118
# 4      29.699118
#          ...
# 886    29.699118
# 887    29.699118
# 888    29.699118
# 889    29.699118
# 890    29.699118
# Name: mean_age, Length: 891, dtype: float64

# %%
df["age","mean_age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dell\Documents\code\myenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('age', 'mean_age')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df["age","mean_age"]
#
# ...

# %%
df[["age","mean_age"]]
# Out:
#       age   mean_age
# 0    22.0  29.699118
# 1    38.0  29.699118
# 2    26.0  29.699118
# 3    35.0  29.699118
# 4    35.0  29.699118
# ..    ...        ...
# 886  27.0  29.699118
# 887  19.0  29.699118
# 888   NaN  29.699118
# 889  26.0  29.699118
# 890  32.0  29.699118
#
# [891 rows x 2 columns]

# %% [markdown]
# ### we use median for miising values when ouliter is present

# %%
df["median_age"]=df["age"].fillna(df["age"]).median()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone   mean_age  median_age
# 0    man        True  NaN  Southampton    no  False  29.699118        28.0
# 1  woman       False    C    Cherbourg   yes  False  29.699118        28.0
# 2  woman       False  NaN  Southampton   yes   True  29.699118        28.0
# 3  woman       False    C  Southampton   yes  False  29.699118        28.0
# 4    man        True  NaN  Southampton    no   True  29.699118        28.0

# %%
df[["age","mean_age","median_age"]]
# Out:
#       age   mean_age  median_age
# 0    22.0  29.699118        28.0
# 1    38.0  29.699118        28.0
# 2    26.0  29.699118        28.0
# 3    35.0  29.699118        28.0
# 4    35.0  29.699118        28.0
# ..    ...        ...         ...
# 886  27.0  29.699118        28.0
# 887  19.0  29.699118        28.0
# 888   NaN  29.699118        28.0
# 889  26.0  29.699118        28.0
# 890  32.0  29.699118        28.0
#
# [891 rows x 3 columns]

# %%
sns.histplot(df["mean_age"],kde=True)
# Out:
# <Axes: xlabel='mean_age', ylabel='Count'>

# %%
sns.histplot(df["median_age"],kde=True)
# Out:
# <Axes: xlabel='median_age', ylabel='Count'>

# %%
df[df["embarked"].isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone   mean_age  median_age
# 61   woman       False    B         NaN   yes   True  29.699118        28.0
# 829  woman       False    B         NaN   yes   True  29.699118        28.0

# %%
df['embarked'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: embarked, Length: 891, dtype: bool

# %% [markdown]
# #### we use mode when categorical values

# %%
mode_value=df[df["embarked"].notna()]["embarked"].mode()[0] ### df['embarked].notnall( this boolen values to df and [embarked] means take values from embarked and calculate mode and [0] we gwet series of mode we take first value)

# %%
mode_value
# Out:
# 'S'

# %%
df[df["embarked"].notna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
#### here we filling null valus in embarked that means in catagrical columns

df["mode_embarked"]=df["embarked"].fillna(mode_value)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone   mean_age  median_age  \
# 0    man        True  NaN  Southampton    no  False  29.699118        28.0
# 1  woman       False    C    Cherbourg   yes  False  29.699118        28.0
# 2  woman       False  NaN  Southampton   yes   True  29.699118        28.0
# 3  woman       False    C  Southampton   yes  False  29.699118        28.0
# 4    man        True  NaN  Southampton    no   True  29.699118        28.0
#
#   mode_age mode_embarked
# 0     22.0             S
# ...

# %%
df.isnull().sum()
# Out:
# survived           0
# pclass             0
# sex                0
# age              177
# sibsp              0
# parch              0
# fare               0
# embarked           2
# class              0
# who                0
# adult_male         0
# deck             688
# embark_town        2
# alive              0
# alone              0
# mean_age           0
# median_age         0
# mode_age           0
# mode_embarked      0
# dtype: int64

# %%
df.drop("mode_age",axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# survived           0
# pclass             0
# sex                0
# age              177
# sibsp              0
# parch              0
# fare               0
# embarked           2
# class              0
# who                0
# adult_male         0
# deck             688
# embark_town        2
# alive              0
# alone              0
# mean_age           0
# median_age         0
# mode_embarked      0
# dtype: int64

# %%
df["mode_1"]=df["embarked"].mode()[0]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone   mean_age  median_age  \
# 0    man        True  NaN  Southampton    no  False  29.699118        28.0
# 1  woman       False    C    Cherbourg   yes  False  29.699118        28.0
# 2  woman       False  NaN  Southampton   yes   True  29.699118        28.0
# 3  woman       False    C  Southampton   yes  False  29.699118        28.0
# 4    man        True  NaN  Southampton    no   True  29.699118        28.0
#
#   mode_embarked mode_1
# 0             S      S
# 1             C      S
# ...

# %%
mode_1=df["embarked"].mode()[0]

# %%
mode_1
# Out:
# 'S'
