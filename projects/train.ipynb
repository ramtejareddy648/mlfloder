# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv("quikr_car.csv")

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
col=car.columns

# %%
col
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
for i in col:
    print(car[i].unique())
# Out:
# ['Hyundai Santro Xing XO eRLX Euro III' 'Mahindra Jeep CL550 MDI'
#  'Maruti Suzuki Alto 800 Vxi' 'Hyundai Grand i10 Magna 1.2 Kappa VTVT'
#  'Ford EcoSport Titanium 1.5L TDCi' 'Ford Figo' 'Hyundai Eon'
#  'Ford EcoSport Ambiente 1.5L TDCi' 'Maruti Suzuki Alto K10 VXi AMT'
#  'Skoda Fabia Classic 1.2 MPI' 'Maruti Suzuki Stingray VXi'
#  'Hyundai Elite i20 Magna 1.2' 'Mahindra Scorpio SLE BS IV' 'Audi A8'
#  'Audi Q7' 'Mahindra Scorpio S10' 'Maruti Suzuki Alto 800'
#  'Hyundai i20 Sportz 1.2' 'Maruti Suzuki Alto 800 Lx'
#  'Maruti Suzuki Vitara Brezza ZDi' 'Maruti Suzuki Alto LX'
#  'Mahindra Bolero DI' 'Maruti Suzuki Swift Dzire ZDi'
#  'Mahindra Scorpio S10 4WD' 'Maruti Suzuki Swift Vdi BSIII'
#  'Maruti Suzuki Wagon R VXi BS III' 'Maruti Suzuki Wagon R VXi Minor'
#  'Toyota Innova 2.0 G 8 STR BS IV' 'Renault Lodgy 85 PS RXL'
#  'Skoda Yeti Ambition 2.0 TDI CR 4x2' 'Maruti Suzuki Baleno Delta 1.2'
#  'Renault Duster 110 PS RxZ Diesel Plus' 'Renault Duster 85 PS RxE Diesel'
# ...

# %%
car['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
print(car['Price'].value_counts())
# Out:
# Price
# Ask For Price    35
# 2,50,000         17
# 3,50,000         14
# 1,80,000         13
# 1,30,000         12
#                  ..
# 12,25,000         1
# 68,000            1
# 9,70,000          1
# 8,60,000          1
# 5,00,001          1
# Name: count, Length: 274, dtype: int64

# %%
car=car[car['Price']!='Ask For Price']

# %%
car.head()
# Out:
#                                      name   company  year     Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  5,75,000
# 6                               Ford Figo      Ford  2012  1,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel
# 6  41,000 kms    Diesel

# %%
car['Price'].isnull().sum()
car['Price']=car['Price'].str.replace(",","")

# %%
car['kms_driven'].isnull().sum()
# Out:
# np.int64(38)

# %%
car['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
car['kms_driven']=car['kms_driven'].str.split(' ').str.get(0)

# %%
car.head()
# Out:
#                                      name   company  year   Price kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000         40
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36,000
# 6                               Ford Figo      Ford  2012  175000     41,000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car['kms_driven']=car['kms_driven'].str.replace(","," ")

# %%
car.head()
# Out:
#                                      name   company  year   Price kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45 000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000         40
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28 000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36 000
# 6                               Ford Figo      Ford  2012  175000     41 000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car['Price'].unique()
# Out:
# array(['80000', '425000', '325000', '575000', '175000', '190000',
#        '830000', '250000', '182000', '315000', '415000', '320000',
#        '1000000', '500000', '350000', '160000', '310000', '75000',
#        '100000', '290000', '95000', '180000', '385000', '105000',
#        '650000', '689999', '448000', '549000', '501000', '489999',
#        '280000', '349999', '284999', '345000', '499999', '235000',
#        '249999', '1475000', '395000', '220000', '170000', '85000',
#        '200000', '570000', '110000', '448999', '1891111', '159500',
#        '344999', '449999', '865000', '699000', '375000', '224999',
#        '1200000', '195000', '351000', '240000', '90000', '155000',
#        '600000', '189500', '210000', '390000', '135000', '1600000',
#        '701000', '265000', '525000', '372000', '635000', '550000',
#        '485000', '329500', '251111', '569999', '69999', '299999',
#        '399999', '450000', '270000', '158400', '179000', '125000',
# ...

# %%
car['kms_driven'].unique()
car['kms_driven']=car['kms_driven'].str.replace(" ","")

# %%
car.head()
# Out:
#                                      name   company  year   Price kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000      45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000         40
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000      28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000      36000
# 6                               Ford Figo      Ford  2012  175000      41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    38
# fuel_type     41
# dtype: int64

# %%
car.shape
# Out:
# (857, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 857 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        857 non-null    object
#  1   company     857 non-null    object
#  2   year        857 non-null    object
#  3   Price       857 non-null    object
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: object(6)
# memory usage: 46.9+ KB

# %%
car['kms_driven'].unique()
# Out:
# array(['45000', '40', '28000', '36000', '41000', '25000', '24530',
#        '60000', '30000', '32000', '48660', '4000', '16934', '43000',
#        '35550', '39522', '39000', '55000', '72000', '15975', '70000',
#        '23452', '35522', '48508', '15487', '82000', '20000', '68000',
#        '38000', '27000', '33000', '46000', '16000', '47000', '35000',
#        '30874', '15000', '29685', '130000', '19000', '54000', '13000',
#        '38200', '22000', '50000', '13500', '3600', '45863', '60500',
#        '12500', '18000', '13349', '29000', '44000', '42000', '14000',
#        '49000', '36200', '51000', '104000', '33333', '33600', '5600',
#        '7500', '26000', '24330', '65480', '200000', '59000', '99000',
#        '2800', '21000', '11000', '66000', '3000', '7000', '38500',
#        '37200', '43200', '24800', '45872', '40000', '11400', '97200',
#        '52000', '31000', '175430', '37000', '65000', '3350', nan, '75000',
# ...

# %%
car=car[car['kms_driven']!='Petrol']

# %%
car.head()
# Out:
#                                      name   company  year   Price kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000      45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000         40
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000      28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000      36000
# 6                               Ford Figo      Ford  2012  175000      41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car['kms_driven'].unique()
# Out:
# array(['45000', '40', '28000', '36000', '41000', '25000', '24530',
#        '60000', '30000', '32000', '48660', '4000', '16934', '43000',
#        '35550', '39522', '39000', '55000', '72000', '15975', '70000',
#        '23452', '35522', '48508', '15487', '82000', '20000', '68000',
#        '38000', '27000', '33000', '46000', '16000', '47000', '35000',
#        '30874', '15000', '29685', '130000', '19000', '54000', '13000',
#        '38200', '22000', '50000', '13500', '3600', '45863', '60500',
#        '12500', '18000', '13349', '29000', '44000', '42000', '14000',
#        '49000', '36200', '51000', '104000', '33333', '33600', '5600',
#        '7500', '26000', '24330', '65480', '200000', '59000', '99000',
#        '2800', '21000', '11000', '66000', '3000', '7000', '38500',
#        '37200', '43200', '24800', '45872', '40000', '11400', '97200',
#        '52000', '31000', '175430', '37000', '65000', '3350', nan, '75000',
# ...

# %%
car['kms_driven']=car['kms_driven'].astype(float)

# %%
mean=car['kms_driven'].mean()

# %%
mean
# Out:
# np.float64(46250.71481028152)

# %%
car.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000        40.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36000.0
# 6                               Ford Figo      Ford  2012  175000     41000.0
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car['kms_driven']=car['kms_driven'].fillna(mean)

# %%
car.head(
)
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000        40.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36000.0
# 6                               Ford Figo      Ford  2012  175000     41000.0
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car['kms_driven'].isnull().sum()
# Out:
# np.int64(0)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 855 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        855 non-null    object
#  1   company     855 non-null    object
#  2   year        855 non-null    object
#  3   Price       855 non-null    object
#  4   kms_driven  855 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 46.8+ KB

# %%
car['Price']=car['Price'].astype(int)

# %%
car.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000        40.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36000.0
# 6                               Ford Figo      Ford  2012  175000     41000.0
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 855 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        855 non-null    object
#  1   company     855 non-null    object
#  2   year        855 non-null    object
#  3   Price       855 non-null    int64
#  4   kms_driven  855 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.8+ KB

# %%
car['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
car.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven     0
# fuel_type     39
# dtype: int64

# %%
car.dropna(inplace=True)

# %%
car.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
car.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000        40.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36000.0
# 6                               Ford Figo      Ford  2012  175000     41000.0
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
car['year'].unique(
)
# Out:
# array(['2007', '2006', '2014', '2012', '2013', '2016', '2015', '2010',
#        '2017', '2008', '2018', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
car['year']=car['year'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 44.6+ KB

# %%
car.reset_index()
# Out:
#      index                                    name   company  year   Price  \
# 0        0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1        1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2        3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 3        4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 4        6                               Ford Figo      Ford  2012  175000
# ..     ...                                     ...       ...   ...     ...
# 811    883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 812    885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 813    886                    Toyota Corolla Altis    Toyota  2009  300000
# 814    888                     Tata Zest XM Diesel      Tata  2018  260000
# 815    889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0       45000.0    Petrol
# ...

# %%
car['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
car.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000        40.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36000.0
# 6                               Ford Figo      Ford  2012  175000     41000.0
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
car['name']=car['name'].str.split().str.slice(0,3).str.join('')

# %%
car.head()
# Out:
#                    name   company  year   Price  kms_driven fuel_type
# 0     HyundaiSantroXing   Hyundai  2007   80000     45000.0    Petrol
# 1     MahindraJeepCL550  Mahindra  2006  425000        40.0    Diesel
# 3       HyundaiGrandi10   Hyundai  2014  325000     28000.0    Petrol
# 4  FordEcoSportTitanium      Ford  2014  575000     36000.0    Diesel
# 6              FordFigo      Ford  2012  175000     41000.0    Diesel

# %%
car.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
car.drop_duplicates()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0       HyundaiSantroXing   Hyundai  2007   80000     45000.0    Petrol
# 1       MahindraJeepCL550  Mahindra  2006  425000        40.0    Diesel
# 3         HyundaiGrandi10   Hyundai  2014  325000     28000.0    Petrol
# 4    FordEcoSportTitanium      Ford  2014  575000     36000.0    Diesel
# 6                FordFigo      Ford  2012  175000     41000.0    Diesel
# ..                    ...       ...   ...     ...         ...       ...
# 883      MarutiSuzukiRitz    Maruti  2011  270000     50000.0    Petrol
# 885          TataIndicaV2      Tata  2009  110000     30000.0    Diesel
# 886    ToyotaCorollaAltis    Toyota  2009  300000    132000.0    Petrol
# 888            TataZestXM      Tata  2018  260000     27000.0    Diesel
# 889      MahindraQuantoC8  Mahindra  2013  390000     40000.0    Diesel
#
# [720 rows x 6 columns]

# %%
car.shape
# Out:
# (816, 6)

# %%
car=car.reset_index(drop=True)

# %%
car.shape
# Out:
# (816, 6)

# %%
car.head()
# Out:
#                    name   company  year   Price  kms_driven fuel_type
# 0     HyundaiSantroXing   Hyundai  2007   80000     45000.0    Petrol
# 1     MahindraJeepCL550  Mahindra  2006  425000        40.0    Diesel
# 2       HyundaiGrandi10   Hyundai  2014  325000     28000.0    Petrol
# 3  FordEcoSportTitanium      Ford  2014  575000     36000.0    Diesel
# 4              FordFigo      Ford  2012  175000     41000.0    Diesel

# %%
car.to_csv('cleaned.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 car.to_csv('cleaned.csv')
#
# NameError: name 'car' is not defined

# %%
car.describe(include='all')
# Out:
#                      name company         year         Price     kms_driven  \
# count                 816     816   816.000000  8.160000e+02     816.000000
# unique                254      25          NaN           NaN            NaN
# top     MarutiSuzukiSwift  Maruti          NaN           NaN            NaN
# freq                   51     221          NaN           NaN            NaN
# mean                  NaN     NaN  2012.444853  4.117176e+05   46275.531863
# std                   NaN     NaN     4.002992  4.751844e+05   34297.428044
# min                   NaN     NaN  1995.000000  3.000000e+04       0.000000
# 25%                   NaN     NaN  2010.000000  1.750000e+05   27000.000000
# 50%                   NaN     NaN  2013.000000  2.999990e+05   41000.000000
# 75%                   NaN     NaN  2015.000000  4.912500e+05   56818.500000
# max                   NaN     NaN  2019.000000  8.500003e+06  400000.000000
#
#        fuel_type
# count        816
# unique         3
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,OrdinalEncoder

# %%
car.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
car.head()
# Out:
#                    name   company  year   Price  kms_driven fuel_type
# 0     HyundaiSantroXing   Hyundai  2007   80000     45000.0    Petrol
# 1     MahindraJeepCL550  Mahindra  2006  425000        40.0    Diesel
# 2       HyundaiGrandi10   Hyundai  2014  325000     28000.0    Petrol
# 3  FordEcoSportTitanium      Ford  2014  575000     36000.0    Diesel
# 4              FordFigo      Ford  2012  175000     41000.0    Diesel

# %%
x=car[['name','company','year','kms_driven','fuel_type']]

# %%
y=car['Price']

# %%
x
# Out:
#                      name   company  year  kms_driven fuel_type
# 0       HyundaiSantroXing   Hyundai  2007     45000.0    Petrol
# 1       MahindraJeepCL550  Mahindra  2006        40.0    Diesel
# 2         HyundaiGrandi10   Hyundai  2014     28000.0    Petrol
# 3    FordEcoSportTitanium      Ford  2014     36000.0    Diesel
# 4                FordFigo      Ford  2012     41000.0    Diesel
# ..                    ...       ...   ...         ...       ...
# 811      MarutiSuzukiRitz    Maruti  2011     50000.0    Petrol
# 812          TataIndicaV2      Tata  2009     30000.0    Diesel
# 813    ToyotaCorollaAltis    Toyota  2009    132000.0    Petrol
# 814            TataZestXM      Tata  2018     27000.0    Diesel
# 815      MahindraQuantoC8  Mahindra  2013     40000.0    Diesel
#
# [816 rows x 5 columns]

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 811    270000
# 812    110000
# 813    300000
# 814    260000
# 815    390000
# Name: Price, Length: 816, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_train
# Out:
#                    name   company  year  kms_driven fuel_type
# 534    MahindraXUV500W6  Mahindra  2014     45000.0    Diesel
# 645    MarutiSuzukiOmni    Maruti  2009     45000.0    Petrol
# 642        TataSumoGold      Tata  2014    116000.0    Diesel
# 593  MahindraScorpioSLX  Mahindra  2008     70000.0    Diesel
# 398     HyundaiCreta1.6   Hyundai  2016     25000.0    Petrol
# ..                  ...       ...   ...         ...       ...
# 507    MarutiSuzukiRitz    Maruti  2010     72160.0    Diesel
# 754          TataBoltXM      Tata  2015     15000.0    Petrol
# 432    MahindraTUV300T4  Mahindra  2016     35000.0    Diesel
# 22     Hyundaii20Sportz   Hyundai  2012     55000.0    Petrol
# 329     RenaultScalaRxL   Renault  2015     25000.0    Diesel
#
# [612 rows x 5 columns]

# %%
car.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
one=OneHotEncoder()
one.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
one.categories_
# Out:
# [array(['AudiA3Cabriolet', 'AudiA41.8', 'AudiA42.0', 'AudiA62.0', 'AudiA8',
#         'AudiQ32.0', 'AudiQ52.0', 'AudiQ7', 'BMW3Series', 'BMW5Series',
#         'BMW7Series', 'BMWX1', 'BMWX1sDrive20d', 'BMWX1xDrive20d',
#         'ChevroletBeat', 'ChevroletBeatDiesel', 'ChevroletBeatLS',
#         'ChevroletBeatLT', 'ChevroletBeatPS', 'ChevroletCruzeLTZ',
#         'ChevroletEnjoy', 'ChevroletEnjoy1.4', 'ChevroletSail1.2',
#         'ChevroletSailUVA', 'ChevroletSpark', 'ChevroletSpark1.0',
#         'ChevroletSparkLS', 'ChevroletSparkLT', 'ChevroletTaveraLS',
#         'ChevroletTaveraNeo', 'DatsunGOT', 'DatsunGoPlus', 'DatsunRediGO',
#         'FiatLineaEmotion', 'FiatPetraELX', 'FiatPuntoEmotion',
#         'ForceMotorsForce', 'ForceMotorsOne', 'FordEcoSport',
#         'FordEcoSportAmbiente', 'FordEcoSportTitanium',
#         'FordEcoSportTrend', 'FordEndeavor4x4', 'FordFiesta',
#         'FordFiestaSXi', 'FordFigo', 'FordFigoDiesel', 'FordFigoDuratorq',
# ...

# %%
from sklearn.compose import ColumnTransformer

transformer=ColumnTransformer([('one_hot',OneHotEncoder(categories=one.categories_),['name','company','fuel_type'])],remainder='passthrough')

# %%
from sklearn.linear_model import LinearRegression

linear=LinearRegression()

# %%
from sklearn.pipeline import make_pipeline
Pipeline=make_pipeline(transformer,linear)

# %%
Pipeline.fit(x_train,y_train)
# Out:
# c:\Users\dell\Documents\code\myenv\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one_hot',
#                                                   OneHotEncoder(categories=[array(['AudiA3Cabriolet', 'AudiA41.8', 'AudiA42.0', 'AudiA62.0', 'AudiA8',
#        'AudiQ32.0', 'AudiQ52.0', 'AudiQ7', 'BMW3Series', 'BMW5Series',
# ...

# %%
y_pred=Pipeline.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 52604087561.01748
# 142134.79689613127
# 0.5650775326779494

# %%
score=[]
for i in range(1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    linear=LinearRegression()
    Pipeline=make_pipeline(transformer,linear)
    Pipeline.fit(x_train,y_train)
    y_pred=Pipeline.predict(x_test)
    score.append(r2_score(y_test,y_pred))

# %%
print(np.argmax(score))
# Out:
# 4

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=4)
linear=LinearRegression()
Pipeline=make_pipeline(transformer,linear)
Pipeline.fit(x_train,y_train)
y_pred=Pipeline.predict(x_test)

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.7713802528908853

# %%
Pipeline.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['MarutiSuzukiSwift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([463957.43628706])

# %%
import pickle
pickle.dump(Pipeline,open('linear.pkl','wb'))

# %%
Pipeline.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['MarutiSuzukiSwift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([463957.43628706])
