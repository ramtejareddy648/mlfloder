# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('cleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                  name   company  year   Price  kms_driven  \
# 0           0     HyundaiSantroXing   Hyundai  2007   80000     45000.0
# 1           1     MahindraJeepCL550  Mahindra  2006  425000        40.0
# 2           2       HyundaiGrandi10   Hyundai  2014  325000     28000.0
# 3           3  FordEcoSportTitanium      Ford  2014  575000     36000.0
# 4           4              FordFigo      Ford  2012  175000     41000.0
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel

# %%
df.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                    name   company  year   Price  kms_driven fuel_type
# 12    HyundaiSantroXing   Hyundai  2007   80000     45000.0    Petrol
# 13    MahindraJeepCL550  Mahindra  2006  425000        40.0    Diesel
# 18   MahindraScorpioS10  Mahindra  2016  350000     43000.0    Diesel
# 22     Hyundaii20Sportz   Hyundai  2012  100000     55000.0    Petrol
# 23     Hyundaii20Sportz   Hyundai  2012  100000     55000.0    Petrol
# ..                  ...       ...   ...     ...         ...       ...
# 603   MarutiSuzukiSwift    Maruti  2012  280000     48006.0    Diesel
# 684   MahindraScorpioS4  Mahindra  2015  865000     30000.0    Diesel
# 742   MarutiSuzukiSwift    Maruti  2009  120000     90000.0    Diesel
# 790    HyundaiGetzPrime   Hyundai  2009  115000     20000.0    Petrol
# 809   MarutiSuzukiSwift    Maruti  2009  250000     51000.0    Diesel
#
# [96 rows x 6 columns]

# %%
df=df.drop_duplicates(keep='first')

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, company, year, Price, kms_driven, fuel_type]
# Index: []

# %%
import matplotlib.pyplot as plt
plt.scatter(df['kms_driven'],df['Price'])

# %%
import seaborn as sns

# %%
sns.regplot(x=df['kms_driven'],y=df['Price'])
# Out:
# <Axes: xlabel='kms_driven', ylabel='Price'>

# %%
numeric_df = df.select_dtypes(include=['number'])  # Keep only numeric columns
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.show()

# %%
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                    name   company  year   Price  kms_driven fuel_type
# 0     HyundaiSantroXing   Hyundai  2007   80000     45000.0    Petrol
# 1     MahindraJeepCL550  Mahindra  2006  425000        40.0    Diesel
# 2       HyundaiGrandi10   Hyundai  2014  325000     28000.0    Petrol
# 3  FordEcoSportTitanium      Ford  2014  575000     36000.0    Diesel
# 4              FordFigo      Ford  2012  175000     41000.0    Diesel

# %%
x=df.drop(columns=['Price'],axis=1)
y=df['Price']

# %%
df['age']=2025-df['year']

# %%
df.head()
# Out:
#                    name   company  year   Price  kms_driven fuel_type  age
# 0     HyundaiSantroXing   Hyundai  2007   80000     45000.0    Petrol   18
# 1     MahindraJeepCL550  Mahindra  2006  425000        40.0    Diesel   19
# 2       HyundaiGrandi10   Hyundai  2014  325000     28000.0    Petrol   11
# 3  FordEcoSportTitanium      Ford  2014  575000     36000.0    Diesel   11
# 4              FordFigo      Ford  2012  175000     41000.0    Diesel   13

# %%
df.drop(columns=['year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                    name   company   Price  kms_driven fuel_type  age
# 0     HyundaiSantroXing   Hyundai   80000     45000.0    Petrol   18
# 1     MahindraJeepCL550  Mahindra  425000        40.0    Diesel   19
# 2       HyundaiGrandi10   Hyundai  325000     28000.0    Petrol   11
# 3  FordEcoSportTitanium      Ford  575000     36000.0    Diesel   11
# 4              FordFigo      Ford  175000     41000.0    Diesel   13

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_train
# Out:
#                       name     company  kms_driven fuel_type  age
# 320        HyundaiElitei20     Hyundai      9000.0    Petrol    9
# 92           ToyotaEtiosGD      Toyota     60000.0    Diesel   12
# 558           TataIndigoCS        Tata    104000.0    Diesel    9
# 442          HyundaiEonEra     Hyundai      2110.0    Petrol    7
# 290      MarutiSuzukiSwift      Maruti        73.0    Petrol    6
# ..                     ...         ...         ...       ...  ...
# 653  MitsubishiPajeroSport  Mitsubishi     37000.0    Diesel   10
# 203        HyundaiGrandi10     Hyundai     20000.0    Petrol   11
# 580          TataManzaAqua        Tata    200000.0    Diesel   11
# 282   FordEcoSportTitanium        Ford     30000.0    Diesel    9
# 96              BMW7Series         BMW     35000.0    Petrol   16
#
# [540 rows x 5 columns]

# %%
df['name'].unique()
# Out:
# array(['HyundaiSantroXing', 'MahindraJeepCL550', 'HyundaiGrandi10',
#        'FordEcoSportTitanium', 'FordFigo', 'HyundaiEon',
#        'FordEcoSportAmbiente', 'MarutiSuzukiAlto', 'SkodaFabiaClassic',
#        'MarutiSuzukiStingray', 'HyundaiElitei20', 'MahindraScorpioSLE',
#        'AudiA8', 'AudiQ7', 'MahindraScorpioS10', 'Hyundaii20Sportz',
#        'MarutiSuzukiVitara', 'MahindraBoleroDI', 'MarutiSuzukiSwift',
#        'MarutiSuzukiWagon', 'ToyotaInnova2.0', 'RenaultLodgy85',
#        'SkodaYetiAmbition', 'MarutiSuzukiBaleno', 'RenaultDuster110',
#        'RenaultDuster85', 'HondaCity1.5', 'MarutiSuzukiDzire',
#        'HondaAmaze', 'HondaAmaze1.5', 'HondaCity', 'DatsunRediGO',
#        'MarutiSuzukiSX4', 'MitsubishiPajeroSport', 'HondaCityZX',
#        'TataIndigoeCS', 'VolkswagenPoloHighline', 'ChevroletSparkLS',
#        'RenaultDuster110PS', 'MiniCooperS', 'SkodaFabia1.2L',
#        'RenaultDuster', 'MahindraScorpioS4', 'MahindraScorpioVLX',
# ...

# %%
df['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
df['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
one=OneHotEncoder()
one.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
one.categories_
# Out:
# [array(['AudiA3Cabriolet', 'AudiA41.8', 'AudiA42.0', 'AudiA62.0', 'AudiA8',
#         'AudiQ32.0', 'AudiQ52.0', 'AudiQ7', 'BMW3Series', 'BMW5Series',
#         'BMW7Series', 'BMWX1', 'BMWX1sDrive20d', 'BMWX1xDrive20d',
#         'ChevroletBeat', 'ChevroletBeatDiesel', 'ChevroletBeatLS',
#         'ChevroletBeatLT', 'ChevroletBeatPS', 'ChevroletCruzeLTZ',
#         'ChevroletEnjoy', 'ChevroletEnjoy1.4', 'ChevroletSail1.2',
#         'ChevroletSailUVA', 'ChevroletSpark', 'ChevroletSpark1.0',
#         'ChevroletSparkLS', 'ChevroletSparkLT', 'ChevroletTaveraLS',
#         'ChevroletTaveraNeo', 'DatsunGOT', 'DatsunGoPlus', 'DatsunRediGO',
#         'FiatLineaEmotion', 'FiatPetraELX', 'FiatPuntoEmotion',
#         'ForceMotorsForce', 'ForceMotorsOne', 'FordEcoSport',
#         'FordEcoSportAmbiente', 'FordEcoSportTitanium',
#         'FordEcoSportTrend', 'FordEndeavor4x4', 'FordFiesta',
#         'FordFiestaSXi', 'FordFigo', 'FordFigoDiesel', 'FordFigoDuratorq',
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler

preprocess=ColumnTransformer(transformers=[
    ('oneencoding',OneHotEncoder(categories=one.categories_),['name','company','fuel_type']),
    ('scale',StandardScaler(),['age','kms_driven'])
],remainder='passthrough')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
from sklearn.svm import  SVR

# %%
models={
    'linear':LinearRegression(),
    'lasso':Lasso(),
    'ridge':Ridge(),
    'elasticnet':ElasticNet(),
    'svr':SVR(),
    'decision':DecisionTreeRegressor(),
    'random':RandomForestRegressor(),
    'adboot':AdaBoostRegressor(),
    'graident':GradientBoostingRegressor(),
    'kneigbhor':KNeighborsRegressor()
}

# %%
from sklearn.pipeline import make_pipeline

# %%
from sklearn.metrics import r2_score

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    pipe=make_pipeline(preprocess,model)
    pipe.fit(x_train,y_train)
    
    y_train_pred=pipe.predict(x_train)
    y_test_pred=pipe.predict(x_test)
    
    
    print(list(models.keys())[i])
    print('x_train prediction ')
    print('r2score',r2_score(y_train,y_train_pred))
    print('--'*32)
    print('x_test prediction ')
    print('r2_score',r2_score(y_test,y_test_pred))
    print('--end--'*23)
# Out:
# linear
# x_train prediction
# r2score 0.7421189612657257
# ----------------------------------------------------------------
# x_test prediction
# r2_score 0.04069136999061029
# --end----end----end----end----end----end----end----end----end----end----end----end----end----end----end----end----end----end----end----end----end----end----end--
# c:\Users\dell\Documents\code\myenv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3191843258242.7812, tolerance: 13667093752.93446
#   model = cd_fast.sparse_enet_coordinate_descent(
# lasso
# x_train prediction
# r2score 0.7421186285222832
# ----------------------------------------------------------------
# x_test prediction
# r2_score -0.14791306750497868
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor

param_grid = {
    'gradientboostingregressor__n_estimators': [50, 100, 200, 300],
    'gradientboostingregressor__learning_rate': [0.01, 0.1, 0.2, 0.5],
    'gradientboostingregressor__max_depth': [3, 5, 7]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gradient=GradientBoostingRegressor()
pipe=make_pipeline(preprocess,gradient)

# %%
grid=GridSearchCV(estimator=pipe,param_grid=param_grid,cv=5)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('oneencoding',
#                                                                          OneHotEncoder(categories=[array(['AudiA3Cabriolet', 'AudiA41.8', 'AudiA42.0', 'AudiA62.0', 'AudiA8',
#        'AudiQ32.0', 'AudiQ52.0', 'AudiQ7', 'BMW3Series', 'BMW5Series',
#        'BMW7Series', 'BMWX1', 'BMWX1sDrive20d', 'BMWX1xDrive20d',
#        'Che...
#                                                                                                    array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                                          ['name',
#                                                                           'company',
# ...

# %%
y_train_pred=grid.predict(x_train)
y_test_pred=grid.predict(x_test)

# %%
print('r2_score train data is',r2_score(y_train,y_train_pred))
print('r2score test data is',r2_score(y_test,y_test_pred))
# Out:
# r2_score train data is 0.5097621344289405
# r2score test data is 0.2138427682970101

# %%
param_dist = {
    'decisiontreeregressor__max_depth': [None, 10, 20, 30, 40],
    'decisiontreeregressor__min_samples_split': np.arange(2, 10),
    'decisiontreeregressor__min_samples_leaf': np.arange(1, 10),
    'decisiontreeregressor__max_features': [None, 'sqrt', 'log2']
}

# %%
decision=DecisionTreeRegressor()
pipe=make_pipeline(preprocess,decision)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_search = RandomizedSearchCV(
    estimator=pipe,
    param_distributions=param_dist,
    n_iter=20, 
    cv=5, 
    scoring='r2', 
    n_jobs=-1, 
    random_state=42
)

# %%
random_search.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('columntransformer',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('oneencoding',
#                                                                                OneHotEncoder(categories=[array(['AudiA3Cabriolet', 'AudiA41.8', 'AudiA42.0', 'AudiA62.0', 'AudiA8',
#        'AudiQ32.0', 'AudiQ52.0', 'AudiQ7', 'BMW3Series', 'BMW5Series',
#        'BMW7Series', 'BMWX1', 'BMWX1sDrive20d', 'BMWX1xDrive20d...
#                                              ('decisiontreeregressor',
#                                               DecisionTreeRegressor())]),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'decisiontreeregressor__max_depth': [None,
#                                                                              10,
# ...

# %%
y_train_pred=random_search.predict(x_train)
y_test_pred=random_search.predict(x_test)

# %%
print('r2_score train data is',r2_score(y_train,y_train_pred))
print('r2score test data is',r2_score(y_test,y_test_pred))
# Out:
# r2_score train data is 0.4300418966080962
# r2score test data is -0.5704839634474672
