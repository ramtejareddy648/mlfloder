# %% [markdown]
# #### polynomial regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=6*np.random.rand(100,1)-3

# %%
x
# Out:
# array([[-1.98826155],
#        [-0.83288733],
#        [-2.35414104],
#        [ 2.75301708],
#        [-0.90401633],
#        [-0.35526054],
#        [ 0.02532428],
#        [-0.34309094],
#        [ 0.37147932],
#        [ 2.35825698],
#        [ 0.49193914],
#        [-2.12941893],
#        [ 1.06223583],
#        [ 0.93010714],
#        [ 0.07339784],
#        [-2.68977625],
#        [-1.80473068],
#        [-2.10805765],
#        [-0.20969947],
#        [-1.1554662 ],
#        [-0.48185928],
#        [-0.96205676],
#        [-0.28670861],
#        [ 0.20915154],
#        [ 2.16247623],
#        [-2.57794378],
#        [-1.06067354],
#        [-1.51991588],
#        [ 1.07257135],
#        [ 2.1248891 ],
#        [ 1.84028125],
#        [-0.35812659],
#        [-0.01974456],
#        [-1.99918075],
#        [-1.00861042],
#        [ 0.30485949],
#        [-1.56870185],
#        [-2.28687518],
#        [ 0.0672568 ],
#        [-2.07594828],
#        [-2.0357518 ],
# ...

# %%
y=0.5*x**2+1.5*x+2+np.random.rand(100,1)

# %%
y
# Out:
# array([[ 5.33710763],
#        [ 6.34293482],
#        [10.3939169 ],
#        [ 4.20647799],
#        [ 7.28106501],
#        [ 9.81663978],
#        [ 8.23058869],
#        [ 2.05837199],
#        [ 8.80171737],
#        [ 1.97364803],
#        [ 2.63763668],
#        [ 6.04925537],
#        [ 2.29234788],
#        [11.31669733],
#        [ 1.63859377],
#        [ 4.67564072],
#        [ 2.3837264 ],
#        [ 1.82676655],
#        [ 4.20142579],
#        [ 3.46531135],
#        [11.46941392],
#        [ 3.97497871],
#        [ 1.3495391 ],
#        [ 1.38817437],
#        [ 1.69387426],
#        [ 7.17078227],
#        [ 9.71375719],
#        [ 7.08474828],
#        [ 3.71798864],
#        [ 1.37900886],
#        [ 3.99086   ],
#        [10.03927091],
#        [ 1.07997333],
#        [ 1.58771071],
#        [ 1.24021923],
#        [11.01293409],
#        [ 2.05189944],
#        [ 6.74351042],
#        [ 1.23907281],
#        [ 7.64907064],
#        [ 2.52026507],
# ...

# %%
plt.scatter(x,y,color='g')
plt.xlabel("x values")
plt.ylabel("y value")
# Out:
# Text(0, 0.5, 'y value')

# %%
df=pd.DataFrame(x)

# %%
df1=pd.DataFrame(y)

# %%
df=pd.concat([df,df1],axis=1)

# %%
df
# Out:
#            0          0
# 0   1.417617   5.337108
# 1   1.580362   6.342935
# 2   2.856063  10.393917
# 3   0.707709   4.206478
# 4   1.789158   7.281065
# ..       ...        ...
# 95 -2.445361   2.093531
# 96  1.151501   5.093529
# 97  2.562772   9.675936
# 98 -1.929176   1.056132
# 99 -2.511630   2.332958
#
# [100 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
# array([[ 1.20883783],
#        [ 0.15456159],
#        [ 1.15150107],
#        [-0.92371526],
#        [-2.34807018],
#        [ 1.51890888],
#        [ 2.9300452 ],
#        [ 0.70873174],
#        [ 0.53749976],
#        [ 2.53760768],
#        [ 2.60661511],
#        [ 0.44907423],
#        [-1.82420459],
#        [ 2.91987369],
#        [-0.31269945],
#        [ 2.89701662],
#        [-2.34618866],
#        [-0.35723077],
#        [-2.44536137],
#        [ 1.81486327],
#        [ 0.7291837 ],
#        [ 0.2193116 ],
#        [ 2.04673848],
#        [-2.72480705],
#        [ 2.86966   ],
#        [-2.65843141],
#        [ 0.70770888],
#        [-0.92955211],
#        [-2.33722653],
#        [ 2.41112363],
#        [ 1.65032779],
#        [ 2.30230065],
#        [-2.11339032],
#        [-2.98343082],
#        [ 1.39269744],
#        [ 0.63008694],
#        [-2.51163003],
#        [-2.96780519],
#        [-2.68639622],
#        [-2.70262062],
#        [-1.59020268],
# ...

# %%
print(x_train.shape)
y_train.shape
# Out:
# (75, 1)
# (75, 1)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.predict(x_test))
# Out:
# [[6.407118  ]
#  [5.79255828]
#  [4.24743061]
#  [0.46095338]
#  [1.20223182]
#  [7.32800407]
#  [1.84213125]
#  [6.82201546]
#  [4.36752087]
#  [6.40616024]
#  [5.62911678]
#  [5.2676181 ]
#  [2.06886673]
#  [0.94188022]
#  [5.5447994 ]
#  [6.96133351]
#  [7.30733978]
#  [7.31715655]
#  [3.50723376]
#  [8.43521394]
#  [6.7329648 ]
#  [0.26115724]
#  [8.18442484]
#  [2.06839228]
#  [5.08617775]]

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg.predict(x_test))

# %%
score
##pred=reg.predict(x_test)
# Out:
# 0.8359041717880085

# %%
resudals=y_test-pred

# %%
resudals
# Out:
# array([[-0.88509411],
#        [-0.84882071],
#        [-1.70466655],
#        [ 1.57240637],
#        [ 0.10233291],
#        [ 0.32106657],
#        [-0.49259215],
#        [-0.01349536],
#        [-1.72988419],
#        [-1.06905262],
#        [-1.42769099],
#        [-1.27675811],
#        [-0.65982805],
#        [ 0.64583049],
#        [-1.07280732],
#        [ 0.31973149],
#        [ 0.13654168],
#        [ 0.51515022],
#        [-1.21488588],
#        [ 1.60405696],
#        [-0.33755046],
#        [ 1.70083327],
#        [ 1.52933235],
#        [-0.29224539],
#        [-1.4882674 ]])

# %%
import seaborn as sns
sns.displot(resudals,kind="kde")

# %%
plt.plot(x_train,reg.predict(x_train))
plt.scatter(x_train,y_train)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2,include_bias=True)

# %%
poly
# Out:
# PolynomialFeatures()

# %%
x_trainpoly=poly.fit_transform(x_train)
x_testpoly=poly.transform(x_test)

# %%
x_trainpoly
# Out:
# array([[ 1.00000000e+00,  1.20883783e+00,  1.46128890e+00],
#        [ 1.00000000e+00,  1.54561589e-01,  2.38892848e-02],
#        [ 1.00000000e+00,  1.15150107e+00,  1.32595470e+00],
#        [ 1.00000000e+00, -9.23715261e-01,  8.53249884e-01],
#        [ 1.00000000e+00, -2.34807018e+00,  5.51343356e+00],
#        [ 1.00000000e+00,  1.51890888e+00,  2.30708417e+00],
#        [ 1.00000000e+00,  2.93004520e+00,  8.58516490e+00],
#        [ 1.00000000e+00,  7.08731736e-01,  5.02300673e-01],
#        [ 1.00000000e+00,  5.37499761e-01,  2.88905993e-01],
#        [ 1.00000000e+00,  2.53760768e+00,  6.43945271e+00],
#        [ 1.00000000e+00,  2.60661511e+00,  6.79444234e+00],
#        [ 1.00000000e+00,  4.49074231e-01,  2.01667665e-01],
#        [ 1.00000000e+00, -1.82420459e+00,  3.32772238e+00],
#        [ 1.00000000e+00,  2.91987369e+00,  8.52566234e+00],
#        [ 1.00000000e+00, -3.12699447e-01,  9.77809441e-02],
#        [ 1.00000000e+00,  2.89701662e+00,  8.39270530e+00],
# ...

# %%
x_trainpoly.shape
# Out:
# (75, 3)

# %%
x_testpoly.shape
# Out:
# (25, 3)

# %%
reg1=LinearRegression()
reg1.fit(x_trainpoly,y_train)
# Out:
# LinearRegression()

# %%
pred1=reg1.predict(x_testpoly)

# %%
y_test
# Out:
# array([[ 5.52202389],
#        [ 4.94373757],
#        [ 2.54276407],
#        [ 2.03335975],
#        [ 1.30456473],
#        [ 7.64907064],
#        [ 1.3495391 ],
#        [ 6.8085201 ],
#        [ 2.63763668],
#        [ 5.33710763],
#        [ 4.20142579],
#        [ 3.99086   ],
#        [ 1.40903868],
#        [ 1.58771071],
#        [ 4.47199208],
#        [ 7.28106501],
#        [ 7.44388146],
#        [ 7.83230677],
#        [ 2.29234788],
#        [10.03927091],
#        [ 6.39541434],
#        [ 1.96199051],
#        [ 9.71375719],
#        [ 1.77614689],
#        [ 3.59791035]])

# %%
score1=r2_score(y_test,pred1)

# %%
score1
# Out:
# 0.9918024718232947

# %%
score2=r2_score(y_train,reg1.predict(x_trainpoly))

# %%
score2
# Out:
# 0.9900285001684729

# %%
x_new=np.linspace(-3,3,200).reshape(200,1)
x_newpoly=poly.transform(x_new)
print(x_newpoly)
# Out:
# [[ 1.00000000e+00 -3.00000000e+00  9.00000000e+00]
#  [ 1.00000000e+00 -2.96984925e+00  8.82000455e+00]
#  [ 1.00000000e+00 -2.93969849e+00  8.64182723e+00]
#  [ 1.00000000e+00 -2.90954774e+00  8.46546804e+00]
#  [ 1.00000000e+00 -2.87939698e+00  8.29092700e+00]
#  [ 1.00000000e+00 -2.84924623e+00  8.11820409e+00]
#  [ 1.00000000e+00 -2.81909548e+00  7.94729931e+00]
#  [ 1.00000000e+00 -2.78894472e+00  7.77821267e+00]
#  [ 1.00000000e+00 -2.75879397e+00  7.61094417e+00]
#  [ 1.00000000e+00 -2.72864322e+00  7.44549380e+00]
#  [ 1.00000000e+00 -2.69849246e+00  7.28186157e+00]
#  [ 1.00000000e+00 -2.66834171e+00  7.12004747e+00]
#  [ 1.00000000e+00 -2.63819095e+00  6.96005151e+00]
#  [ 1.00000000e+00 -2.60804020e+00  6.80187369e+00]
#  [ 1.00000000e+00 -2.57788945e+00  6.64551400e+00]
#  [ 1.00000000e+00 -2.54773869e+00  6.49097245e+00]
#  [ 1.00000000e+00 -2.51758794e+00  6.33824903e+00]
#  [ 1.00000000e+00 -2.48743719e+00  6.18734375e+00]
# ...

# %%
y_new=reg1.predict(x_newpoly)

# %%
y_new.shape
# Out:
# (200, 1)

# %%
x_newpoly.shape
# Out:
# (200, 3)

# %%
plt.plot(x_new,y_new)

# %%
plt.scatter(x_train,y_train)

# %% [markdown]
# ### pipe line

# %%
from sklearn.pipeline import Pipeline

def polynomial(degree):
    x_new=np.linspace(-3,3,200).reshape(200,1)
    poly=PolynomialFeatures(degree=degree,include_bias=True)
    linear=LinearRegression()
    pipe=Pipeline([("poly feature",poly),("regression",linear)])
    pipe.fit(x_train,y_train)
    y_new_pred=pipe.predict(x_new)
    print(y_new_pred)
    plt.plot(x_new, y_new_pred,'r', label="Degree " + str(degree), linewidth=2)
    plt.plot(x_train, y_train, "b.", linewidth=3)
    plt.plot(x_test, y_test, "g.", linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.axis([-4,4, 0, 10])
    plt.show()

# %%
polynomial(5)
# Out:
# [[ 2.37475106]
#  [ 2.34152916]
#  [ 2.30807578]
#  [ 2.27444822]
#  [ 2.24070229]
#  [ 2.20689236]
#  [ 2.17307135]
#  [ 2.13929075]
#  [ 2.10560064]
#  [ 2.07204969]
#  [ 2.03868522]
#  [ 2.00555314]
#  [ 1.97269806]
#  [ 1.94016323]
#  [ 1.90799058]
#  [ 1.87622076]
#  [ 1.84489312]
#  [ 1.81404575]
#  [ 1.78371549]
#  [ 1.75393795]
#  [ 1.72474749]
#  [ 1.69617732]
#  [ 1.6682594 ]
#  [ 1.64102458]
#  [ 1.61450251]
#  [ 1.58872173]
#  [ 1.56370965]
#  [ 1.53949255]
#  [ 1.51609566]
#  [ 1.49354311]
#  [ 1.47185797]
#  [ 1.45106229]
#  [ 1.43117707]
#  [ 1.41222233]
#  [ 1.39421705]
#  [ 1.37717928]
#  [ 1.36112609]
#  [ 1.3460736 ]
#  [ 1.33203701]
#  [ 1.31903059]
#  [ 1.30706774]
#  [ 1.29616096]
#  [ 1.2863219 ]
#  [ 1.27756134]
#  [ 1.26988926]
#  [ 1.26331479]
#  [ 1.25784628]
#  [ 1.25349129]
#  [ 1.25025661]
#  [ 1.2481483 ]
#  [ 1.24717165]
#  [ 1.24733126]
#  [ 1.24863101]
#  [ 1.2510741 ]
#  [ 1.25466306]
#  [ 1.25939975]
#  [ 1.26528542]
#  [ 1.27232067]
# ...
